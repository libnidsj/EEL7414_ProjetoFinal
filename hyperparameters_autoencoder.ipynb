# %% [markdown]
# # 1. Download e tratamento do DataSet

# %% [markdown]
# ## 1.1. Download dos dados

# %%
import os
import gc
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_squared_error
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Carregamento do dataset

# %%
# Caminhos dos diretórios
train_watermarked_path = 'CLWD/train/Watermarked_image'
train_non_watermarked_path = 'CLWD/train/Watermark_free_image'
test_watermarked_path = 'CLWD/test/Watermarked_image'
test_non_watermarked_path = 'CLWD/test/Watermark_free_image'
results_filename = 'hyperparameter_autoencoder'

# Parâmetros
batch_size = 32
validation_split = 0.2
img_dim = 64
img_size = (img_dim, img_dim)
steps_per_epoch = (1 - validation_split) * len(os.listdir(train_watermarked_path)) // batch_size
validation_steps = validation_split * len(os.listdir(train_watermarked_path)) // batch_size

# %%
def create_dataset(watermarked_path, non_watermarked_path, img_size, batch_size, validation_split=0.2, subset=None, shuffle=True):
    # Lista de arquivos
    watermarked_files = sorted([os.path.join(watermarked_path, f) for f in os.listdir(watermarked_path)])
    non_watermarked_files = sorted([os.path.join(non_watermarked_path, f) for f in os.listdir(non_watermarked_path)])

    # Certifique-se de que os arquivos correspondem em ordem
    assert len(watermarked_files) == len(non_watermarked_files), "Os conjuntos de dados devem ter o mesmo tamanho."
    
    # Determinar índice de divisão
    split_index = int(len(watermarked_files) * (1 - validation_split))

    if subset == "training":
        watermarked_files = watermarked_files[:split_index]
        non_watermarked_files = non_watermarked_files[:split_index]
    elif subset == "validation":
        watermarked_files = watermarked_files[split_index:]
        non_watermarked_files = non_watermarked_files[split_index:]

    # Criar dataset com pares de caminhos
    dataset = tf.data.Dataset.from_tensor_slices((watermarked_files, non_watermarked_files))

    # Função para carregar e pré-processar as imagens
    def preprocess(w_file, nw_file):
        w_img = tf.io.read_file(w_file)
        w_img = tf.image.decode_jpeg(w_img, channels=3)
        w_img = tf.image.resize(w_img, img_size) / 255.0

        nw_img = tf.io.read_file(nw_file)
        nw_img = tf.image.decode_jpeg(nw_img, channels=3)
        nw_img = tf.image.resize(nw_img, img_size) / 255.0

        return w_img, nw_img

    # Aplicar pré-processamento
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

    # Embaralhar se necessário
    if shuffle and subset == "training":
        dataset = dataset.shuffle(buffer_size=1000)

    # Dividir em lotes e aplicar prefetch
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset

# %% [markdown]
# # 3. Construção do Autoencoder Convolucional

# %%
def build_autoencoder(input_shape=(64, 64, 3)):
    input_img = Input(shape=input_shape)

    # Encoder
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)

    # Decoder
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

    autoencoder = Model(input_img, decoded)
    return autoencoder

# Instanciar o modelo
autoencoder = build_autoencoder()
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Adicionar callbacks
callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',  # Monitora a perda de validação
        factor=0.5,          # Reduz a taxa de aprendizado pela metade
        patience=3,          # Espera 3 épocas sem melhora
        verbose=1
    ),
    EarlyStopping(
        monitor='val_loss',  # Monitora a perda de validação
        patience=6,          # Para após 6 épocas sem melhora
        restore_best_weights=True  # Restaura os melhores pesos encontrados
    ),
    ModelCheckpoint(
        filepath='best_hyp_model.h5',  # Salva o melhor modelo
        monitor='val_loss',  # Monitora a perda de validação
        save_best_only=True, # Salva apenas se for o melhor modelo
        verbose=1
    )
]

autoencoder.summary()

# Liberação de memória
gc.collect()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  up_sampling2d (UpSampling2D  (None, 32, 32, 128)      0
#  )
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        73792
#
#  up_sampling2d_1 (UpSampling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 3)         1731
#
# =================================================================
# Total params: 298,755
# Trainable params: 298,755
# Non-trainable params: 0
# _________________________________________________________________
# 20

# %% [markdown]
# # 4. Treinamento do modelo

# %%
train_dataset = create_dataset(
    train_watermarked_path, train_non_watermarked_path, 
    img_size, batch_size, validation_split=validation_split, subset="training"
)

val_dataset = create_dataset(
    train_watermarked_path, train_non_watermarked_path, 
    img_size, batch_size, validation_split=validation_split, subset="validation"
)

with tf.device("/device:GPU:0"):
    # Treinamento
    history = autoencoder.fit(
        train_dataset,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_dataset,
        validation_steps=validation_steps,
        callbacks=callbacks,
        epochs=150
    )
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 0.00693, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 32s 20ms/step - loss: 0.0098 - val_loss: 0.0069 - lr: 0.0010
# Epoch 2/150
#
# Epoch 2: val_loss improved from 0.00693 to 0.00579, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 34s 23ms/step - loss: 0.0064 - val_loss: 0.0058 - lr: 0.0010
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.00579 to 0.00536, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 35s 23ms/step - loss: 0.0058 - val_loss: 0.0054 - lr: 0.0010
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.00536 to 0.00502, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 35s 23ms/step - loss: 0.0054 - val_loss: 0.0050 - lr: 0.0010
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.00502 to 0.00498, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 34s 23ms/step - loss: 0.0052 - val_loss: 0.0050 - lr: 0.0010
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.00498 to 0.00496, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0050 - val_loss: 0.0050 - lr: 0.0010
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.00496 to 0.00470, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0049 - val_loss: 0.0047 - lr: 0.0010
# Epoch 8/150
#
# Epoch 8: val_loss did not improve from 0.00470
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0048 - val_loss: 0.0048 - lr: 0.0010
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.00470 to 0.00447, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0047 - val_loss: 0.0045 - lr: 0.0010
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.00447 to 0.00446, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0046 - val_loss: 0.0045 - lr: 0.0010
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.00446 to 0.00439, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0045 - val_loss: 0.0044 - lr: 0.0010
# Epoch 12/150
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_loss improved from 0.00439 to 0.00439, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0045 - val_loss: 0.0044 - lr: 0.0010
# Epoch 13/150
#
# Epoch 13: val_loss did not improve from 0.00439
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0043 - val_loss: 0.0044 - lr: 5.0000e-04
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.00439 to 0.00413, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 35s 23ms/step - loss: 0.0042 - val_loss: 0.0041 - lr: 5.0000e-04
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.00413 to 0.00407, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0042 - val_loss: 0.0041 - lr: 5.0000e-04
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.00407 to 0.00405, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0042 - val_loss: 0.0040 - lr: 5.0000e-04
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.00405 to 0.00399, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0041 - val_loss: 0.0040 - lr: 5.0000e-04
# Epoch 18/150
#
# Epoch 18: val_loss did not improve from 0.00399
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0041 - val_loss: 0.0040 - lr: 5.0000e-04
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.00399 to 0.00395, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0041 - val_loss: 0.0039 - lr: 5.0000e-04
# Epoch 20/150
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_loss did not improve from 0.00395
# 1500/1500 [==============================] - 39s 25ms/step - loss: 0.0040 - val_loss: 0.0040 - lr: 5.0000e-04
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.00395 to 0.00385, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0039 - val_loss: 0.0039 - lr: 2.5000e-04
# Epoch 22/150
#
# Epoch 22: val_loss did not improve from 0.00385
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0039 - val_loss: 0.0039 - lr: 2.5000e-04
# Epoch 23/150
#
# Epoch 23: val_loss improved from 0.00385 to 0.00384, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0039 - val_loss: 0.0038 - lr: 2.5000e-04
# Epoch 24/150
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 24: val_loss improved from 0.00384 to 0.00384, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0039 - val_loss: 0.0038 - lr: 2.5000e-04
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.00384 to 0.00377, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0038 - val_loss: 0.0038 - lr: 1.2500e-04
# Epoch 26/150
#
# Epoch 26: val_loss did not improve from 0.00377
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0038 - val_loss: 0.0038 - lr: 1.2500e-04
# Epoch 27/150
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 27: val_loss did not improve from 0.00377
# 1500/1500 [==============================] - 35s 23ms/step - loss: 0.0038 - val_loss: 0.0038 - lr: 1.2500e-04
# Epoch 28/150
#
# Epoch 28: val_loss improved from 0.00377 to 0.00374, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0038 - val_loss: 0.0037 - lr: 6.2500e-05
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.00374 to 0.00373, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.2500e-05
# Epoch 30/150
#
# Epoch 30: val_loss did not improve from 0.00373
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.2500e-05
# Epoch 31/150
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 31: val_loss improved from 0.00373 to 0.00372, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.2500e-05
# Epoch 32/150
#
# Epoch 32: val_loss did not improve from 0.00372
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.1250e-05
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.00372 to 0.00371, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.1250e-05
# Epoch 34/150
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 34: val_loss improved from 0.00371 to 0.00370, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.1250e-05
# Epoch 35/150
#
# Epoch 35: val_loss improved from 0.00370 to 0.00370, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5625e-05
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.00370 to 0.00369, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5625e-05
# Epoch 37/150
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 37: val_loss did not improve from 0.00369
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5625e-05
# Epoch 38/150
#
# Epoch 38: val_loss improved from 0.00369 to 0.00369, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.8125e-06
# Epoch 39/150
#
# Epoch 39: val_loss did not improve from 0.00369
# 1500/1500 [==============================] - 36s 23ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.8125e-06
# Epoch 40/150
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 40: val_loss improved from 0.00369 to 0.00369, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.8125e-06
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.00369 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.9063e-06
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.9063e-06
# Epoch 43/150
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 43: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.9063e-06
# Epoch 44/150
#
# Epoch 44: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.9531e-06
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.9531e-06
# Epoch 46/150
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 46: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.9531e-06
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 9.7656e-07
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 9.7656e-07
# Epoch 49/150
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 49: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 9.7656e-07
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 4.8828e-07
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 4.8828e-07
# Epoch 52/150
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 52: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 4.8828e-07
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 2.4414e-07
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 2.4414e-07
# Epoch 55/150
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 55: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 2.4414e-07
# Epoch 56/150
#
# Epoch 56: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.2207e-07
# Epoch 57/150
#
# Epoch 57: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.2207e-07
# Epoch 58/150
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
#
# Epoch 58: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.2207e-07
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.1035e-08
# Epoch 60/150
#
# Epoch 60: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.1035e-08
# Epoch 61/150
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
#
# Epoch 61: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 39s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 6.1035e-08
# Epoch 62/150
#
# Epoch 62: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.0518e-08
# Epoch 63/150
#
# Epoch 63: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.0518e-08
# Epoch 64/150
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
#
# Epoch 64: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.0518e-08
# Epoch 65/150
#
# Epoch 65: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 36s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5259e-08
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.00368 to 0.00368, saving model to best_hyp_model.h5
# 1500/1500 [==============================] - 39s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5259e-08
# Epoch 67/150
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
#
# Epoch 67: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 1.5259e-08
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.6294e-09
# Epoch 69/150
#
# Epoch 69: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.6294e-09
# Epoch 70/150
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
#
# Epoch 70: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 7.6294e-09
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.8147e-09
# Epoch 72/150
#
# Epoch 72: val_loss did not improve from 0.00368
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0037 - val_loss: 0.0037 - lr: 3.8147e-09

# %% [markdown]
# # 5. Avaliação e visualização dos resultados

# %%
def plot_training_history(history, output_dir="output", file_name="train_history.png"):

    # Cria o diretório de saída, se necessário
    os.makedirs(output_dir, exist_ok=True)
    
    # Caminho completo para salvar o arquivo
    output_path = os.path.join(output_dir, file_name)
    
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Treinamento', color='blue', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validação', color='orange', linewidth=2)
    plt.title('Perda Durante o Treinamento e Validação', fontsize=16)
    plt.xlabel('Épocas', fontsize=14)
    plt.ylabel('Perda', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.savefig(output_path)  # Salva o plot no arquivo
    print(f"Imagens salvas em: {output_path}")
    plt.show()
    plt.close()

# Chamando a função após o treinamento
plot_training_history(history, output_dir="results", file_name=results_filename+'_training.png')
# Out:
# Imagens salvas em: results\hyperparameter_autoencoder_training.png

# %%
def load_image(file_path, img_size):
    """
    Carrega uma imagem a partir do caminho e redimensiona.
    """
    image = tf.keras.utils.load_img(file_path, target_size=img_size)
    image = tf.keras.utils.img_to_array(image) / 255.0  # Normaliza para [0, 1]
    return image


def create_test_dataset(watermarked_path, non_watermarked_path, img_size, batch_size):
    """
    Cria o dataset de teste com pares de imagens (com e sem marca d'água).
    """
    # Lista arquivos nos diretórios
    watermarked_files = sorted(os.listdir(watermarked_path), key=lambda x: int(x.split('.')[0]))
    non_watermarked_files = sorted(os.listdir(non_watermarked_path), key=lambda x: int(x.split('.')[0]))
    
    # Verifica se os dois conjuntos possuem o mesmo número de arquivos
    assert len(watermarked_files) == len(non_watermarked_files), \
        "O número de arquivos nos dois diretórios deve ser o mesmo."

    # Carrega as imagens
    watermarked_images = [
        load_image(os.path.join(watermarked_path, file), img_size) for file in watermarked_files
    ]
    non_watermarked_images = [
        load_image(os.path.join(non_watermarked_path, file), img_size) for file in non_watermarked_files
    ]

    # Combina em pares
    dataset = tf.data.Dataset.from_tensor_slices((watermarked_images, non_watermarked_images))
    dataset = dataset.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

test_dataset = create_test_dataset(
    test_watermarked_path, test_non_watermarked_path, img_size, batch_size
)

# %%
def evaluate_model_metrics(model, dataset, max_pixel_value=1.0):

    rmse_values = []
    psnr_values = []
    ssim_values = []

    with tf.device("/device:GPU:0"):

        for watermarked, non_watermarked in dataset:
            # Previsão pelo modelo
            reconstructed = model.predict(watermarked, verbose=0)
    
            # Converte para arrays NumPy, se necessário
            y_true = non_watermarked.numpy() if hasattr(non_watermarked, 'numpy') else np.array(non_watermarked)
            y_pred = reconstructed
    
            # Normaliza as imagens, se necessário
            y_true = np.clip(y_true, 0, max_pixel_value)
            y_pred = np.clip(y_pred, 0, max_pixel_value)
    
            # Calcula RMSE
            mse = mean_squared_error(y_true.flatten(), y_pred.flatten())
            rmse = np.sqrt(mse)
            rmse_values.append(rmse)
    
            # Calcula PSNR
            psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse)) if mse > 0 else float('inf')
            psnr_values.append(psnr)
    
            # Calcula SSIM
            ssim_value = ssim(y_true, y_pred, data_range=max_pixel_value, multichannel=True, channel_axis=-1)
            ssim_values.append(ssim_value)

    # Calcula as médias de cada métrica
    metrics = {
        "RMSE": np.mean(rmse_values),
        "PSNR": np.mean(psnr_values),
        "SSIM": np.mean(ssim_values)
    }
    return metrics

# Calcula RMSE no conjunto de treinamento
train_metrics = evaluate_model_metrics(autoencoder, train_dataset)
print("Métricas médias do treinamento:")
print(f"RMSE: {train_metrics['RMSE']:.4f}")
print(f"PSNR: {train_metrics['PSNR']:.2f} dB")
print(f"SSIM: {train_metrics['SSIM']:.4f}")

# Calcula RMSE no conjunto de validacao
val_metrics = evaluate_model_metrics(autoencoder, val_dataset)
print("Métricas médias da validacao:")
print(f"RMSE: {val_metrics['RMSE']:.4f}")
print(f"PSNR: {val_metrics['PSNR']:.2f} dB")
print(f"SSIM: {val_metrics['SSIM']:.4f}")

# Calcula o RMSE no conjunto de teste
test_metrics = evaluate_model_metrics(autoencoder, test_dataset)
print("Métricas médias do teste:")
print(f"RMSE: {test_metrics['RMSE']:.4f}")
print(f"PSNR: {test_metrics['PSNR']:.2f} dB")
print(f"SSIM: {test_metrics['SSIM']:.4f}")
# Out:
# Métricas médias do treinamento:
# RMSE: 0.0605
# PSNR: 24.39 dB
# SSIM: 0.9614
# Métricas médias da validacao:
# RMSE: 0.0605
# PSNR: 24.39 dB
# SSIM: 0.9610
# Métricas médias do teste:
# RMSE: 0.0672
# PSNR: 23.47 dB
# SSIM: 0.9552

# %%
def save_and_show_reconstructed_images(model, test_dataset, num_images=15, output_dir="output", file_name="reconstructed_images.png"):

    # Cria o diretório de saída, se necessário
    os.makedirs(output_dir, exist_ok=True)
    
    # Caminho completo para salvar o arquivo
    output_path = os.path.join(output_dir, file_name)
    
    # Obtém um lote de imagens do dataset de teste
    for watermarked, non_watermarked in test_dataset.take(1):
        # Previsão do modelo
        reconstructed = model.predict(watermarked, verbose=0)

        # Número de imagens a serem plotadas
        num_images = min(num_images, watermarked.shape[0])

        plt.figure(figsize=(15, 5))

        for i in range(num_images):
            # Imagem com marca d'água
            ax = plt.subplot(3, num_images, i + 1)
            plt.imshow(watermarked[i])
            if i == 0:
                plt.title("Com marca d'água")
            plt.axis("off")

            # Imagem original
            ax = plt.subplot(3, num_images, i + 1 + num_images)
            plt.imshow(non_watermarked[i])
            if i == 0:
                plt.title("Original")
            plt.axis("off")

            # Imagem reconstruída
            ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
            plt.imshow(reconstructed[i])
            if i == 0:
                plt.title("Reconstruída")
            plt.axis("off")

        plt.tight_layout()
        plt.savefig(output_path)  # Salva o plot no arquivo
        print(f"Imagens salvas em: {output_path}")
        plt.show()  # Exibe a figura na tela
        plt.close()  # Fecha a figura para liberar memória
        break  # Apenas um lote é necessário

# Plota 15 imagens do conjunto de teste
save_and_show_reconstructed_images(autoencoder, test_dataset, num_images=15, output_dir="results", file_name=results_filename+'_images.png')
# Out:
# Imagens salvas em: results\hyperparameter_autoencoder_images.png

# %% [markdown]
# # 6. Salvar o modelo treinado

# %%
# Salvar o modelo treinado
autoencoder.save('models/'+results_filename+'.h5')
